# %% [markdown]
# # Data Generation for AI Doctor Patient Relationship
#
# This notebook is ignored by Quarto because the filename starts with an underscore.

# %%
import pandas as pd

# Use the 'resolve' URL for the raw file
url = "synthetic_patient_embeddings.parquet"

# Load the entire file
pats_df = pd.read_parquet(url, engine='pyarrow')
pats_df.head()
# Out:
#     patient_id  space_index       nct_id  \
# 0  23894000000         4777  NCT06248515
# 1  23895000000         4777  NCT06248515
# 2  23896000000         4777  NCT06248515
# 3  23897000000         4777  NCT06248515
# 4  23898000000         4778  NCT06248515
#
#                                                title  \
# 0  A Phase II Trial of Sacituzumab Govitecan in P...
# 1  A Phase II Trial of Sacituzumab Govitecan in P...
# 2  A Phase II Trial of Sacituzumab Govitecan in P...
# 3  A Phase II Trial of Sacituzumab Govitecan in P...
# 4  A Phase II Trial of Sacituzumab Govitecan in P...
#
#                                 eligibility_criteria  \
# 0  Inclusion Criteria:\n\n* Age \>/= 18 years at ...
# 1  Inclusion Criteria:\n\n* Age \>/= 18 years at ...
# 2  Inclusion Criteria:\n\n* Age \>/= 18 years at ...
# 3  Inclusion Criteria:\n\n* Age \>/= 18 years at ...
# 4  Inclusion Criteria:\n\n* Age \>/= 18 years at ...
#
#                                           trial_text  \
# 0  A Phase II Trial of Sacituzumab Govitecan in P...
# 1  A Phase II Trial of Sacituzumab Govitecan in P...
# 2  A Phase II Trial of Sacituzumab Govitecan in P...
# 3  A Phase II Trial of Sacituzumab Govitecan in P...
# 4  A Phase II Trial of Sacituzumab Govitecan in P...
#
#                               trial_boilerplate_text  \
# 0  Any disease, metabolic disorder, physical‑exam...
# 1  Any disease, metabolic disorder, physical‑exam...
# 2  Any disease, metabolic disorder, physical‑exam...
# 3  Any disease, metabolic disorder, physical‑exam...
# 4  Any disease, metabolic disorder, physical‑exam...
#
#                                           this_space  space_number  \
# 0  Age range allowed: >= 18 years. Sex allowed: M...             1
# 1  Age range allowed: >= 18 years. Sex allowed: M...             1
# 2  Age range allowed: >= 18 years. Sex allowed: M...             1
# 3  Age range allowed: >= 18 years. Sex allowed: M...             1
# 4  Age range allowed: >= 18 years. Sex allowed: M...             2
#
#                                    patient_long_text  \
# 0  2018-11-10 pathology_report **PATHOLOGY REPORT...
# 1  2011-07-10 pathology_report **Pathology Report...
# 2  2018-08-16 pathology_report **PATHOLOGY REPORT...
# 3  2017-12-14 pathology_report **PATHOLOGY REPORT...
# 4  2014-02-13 pathology_report **PATHOLOGY REPORT...
#
#                 patient_summary_reasoning_and_output  \
# 0  analysisWe need produce summary per instructio...
# 1  analysisWe need produce summary per instructio...
# 2  analysisWe need produce summary per instructio...
# 3  analysisWe need produce summary per instructio...
# 4  analysisWe need produce summary per instructio...
#
#                                      patient_summary  \
# 0  Age: 74  \nSex: Male  \n\nCancer #1: Cutaneous...
# 1  Age: 53  \nSex: Female  \n\nCancer type: Colon...
# 2  Age: 78  \nSex: Male  \n\nCancer type: Prostat...
# 3  Age: 55  \nSex: Female  \n\nCancer type: Papil...
# 4  Age: 22  \nSex: Female  \n\nCancer type: Thymi...
#
#                                  patient_boilerplate  \
# 0  - Controlled brain metastases (stable post‑SRS...
# 1
# 2
# 3  - Chronic kidney disease stage 3b (eGFR ≈38 mL...
# 4  • Liver dysfunction – documented modest transa...
#
#                                patient_summary_trunc  \
# 0  Age: 74  \nSex: Male  \n\nCancer #1: Cutaneous...
# 1  Age: 53  \nSex: Female  \n\nCancer type: Colon...
# 2  Age: 78  \nSex: Male  \n\nCancer type: Prostat...
# 3  Age: 55  \nSex: Female  \n\nCancer type: Papil...
# 4  Age: 22  \nSex: Female  \n\nCancer type: Thymi...
#
#                                    patient_embedding
# 0  [-0.01875578612089157, -0.007208144757896662, ...
# 1  [0.0053234403021633625, -0.03859995678067207, ...
# 2  [-0.025754420086741447, -0.035622477531433105,...
# 3  [-0.011339062824845314, -0.029756037518382072,...
# 4  [-0.004979774355888367, -0.02128094807267189, ...

# %%
# load the trial embeddings
url = "synthetic_trial_embeddings.parquet"

# Load the entire file
trial_df = pd.read_parquet(url, engine='pyarrow')
trial_df.head()
# Out:
#         nct_id  split                                              title  \
# 0  NCT00004847  train                      Diagnosis of Pheochromocytoma
# 1  NCT00004847  train                      Diagnosis of Pheochromocytoma
# 2  NCT00044304  train  Tyrosine Kinase Inhibition to Treat Myeloid Hy...
# 3  NCT00044304  train  Tyrosine Kinase Inhibition to Treat Myeloid Hy...
# 4  NCT00107289  train  Iodine I 131 Metaiodobenzylguanidine in Treati...
#
#                                 eligibility_criteria  \
# 0  * INCLUSION CRITERIA:\n\nPatients are eligible...
# 1  * INCLUSION CRITERIA:\n\nPatients are eligible...
# 2  * INCLUSION CRITERIA:\n\nIn order to be eligib...
# 3  * INCLUSION CRITERIA:\n\nIn order to be eligib...
# 4  Inclusion criteria for NB:\n\n* Patients must ...
#
#                                           trial_text  \
# 0  Diagnosis of Pheochromocytoma\nThe goal of thi...
# 1  Diagnosis of Pheochromocytoma\nThe goal of thi...
# 2  Tyrosine Kinase Inhibition to Treat Myeloid Hy...
# 3  Tyrosine Kinase Inhibition to Treat Myeloid Hy...
# 4  Iodine I 131 Metaiodobenzylguanidine in Treati...
#
#                           space_reasoning_and_output  \
# 0  analysisWe need to parse the trial doc. Identi...
# 1  analysisWe need to parse the trial doc. Identi...
# 2  analysisWe need parse inclusion criteria into ...
# 3  analysisWe need parse inclusion criteria into ...
# 4  analysisWe need parse inclusion criteria separ...
#
#                            space_output_no_reasoning  \
# 0  1. Age range allowed: 3 years and older. Sex a...
# 1  1. Age range allowed: 3 years and older. Sex a...
# 2  1. Age range allowed: ≥2 years. Sex allowed: b...
# 3  1. Age range allowed: ≥2 years. Sex allowed: b...
# 4  1. Age range allowed: greater than 1 year old ...
#
#                                           space_text  \
# 0  1. Age range allowed: 3 years and older. Sex a...
# 1  1. Age range allowed: 3 years and older. Sex a...
# 2  1. Age range allowed: ≥2 years. Sex allowed: b...
# 3  1. Age range allowed: ≥2 years. Sex allowed: b...
# 4  1. Age range allowed: greater than 1 year old ...
#
#                               trial_boilerplate_text  \
# 0  Pregnant or breastfeeding women.\nSevere cardi...
# 1  Pregnant or breastfeeding women.\nSevere cardi...
# 2  Pregnancy or breastfeeding. History of D816V K...
# 3  Pregnancy or breastfeeding. History of D816V K...
# 4  Severe major organ toxicity (renal, cardiac, h...
#
#                                           this_space  space_number  \
# 0  Age range allowed: 3 years and older. Sex allo...             1
# 1  Age range allowed: 18 years and older. Sex all...             2
# 2  Age range allowed: ≥2 years. Sex allowed: both...             1
# 3  Age range allowed: ≥18 years. Sex allowed: bot...             2
# 4  Age range allowed: greater than 1 year old wit...             1
#
#                                     this_space_trunc  \
# 0  Age range allowed: 3 years and older. Sex allo...
# 1  Age range allowed: 18 years and older. Sex all...
# 2  Age range allowed: ≥2 years. Sex allowed: both...
# 3  Age range allowed: ≥18 years. Sex allowed: bot...
# 4  Age range allowed: greater than 1 year old wit...
#
#                                            embedding
# 0  [0.009598778560757637, -0.020862499251961708, ...
# 1  [0.005962436553090811, -0.030283858999609947, ...
# 2  [-0.007195591926574707, -0.02903938665986061, ...
# 3  [-0.009074191562831402, -0.028509285300970078,...
# 4  [0.017702119424939156, -0.0051076365634799, -0...

# %%
# do a basic  keyword search to limit to NSCLC
pats_df['nsclc'] = pats_df.patient_summary.apply(lambda x: x.lower().count("lung cancer") > 1)
trial_df['nsclc'] = trial_df.this_space.apply(lambda x: x.lower().count("nsclc") > 1)

# %%
pats_df[pats_df.nsclc].shape
# Out:
# (133, 16)

# %%
trial_df[trial_df.nsclc].shape
# Out:
# (22, 14)

# %%
print(pats_df.patient_summary.values[9])
# Out:
# Age: 60
# Sex: Male
#
# Cancer type: Non‑small cell lung cancer (NSCLC) – Adenocarcinoma, primary site left upper lobe
#
# Histology: Moderately differentiated adenocarcinoma (predominantly acinar/tubular with focal lepidic)
#
# Current extent: Metastatic (Stage IV, cT2a N2 M1c) – active extrathoracic disease includes adrenal, hepatic, osseous (L3 vertebra, left iliac bone) and pleural metastases; solitary left frontal brain metastasis treated with whole‑brain radiation and currently stable
#
# Biomarkers:
# • PD‑L1 TPS = 20 % (22C3)
# • KRAS G12C mutation (exon 2)
# • MET amplification (~8 copy number)
# • TP53 R175H missense mutation
# • STK11 loss
# • CDKN2A homozygous deletion
# • Low‑level PTEN loss
# • EGFR wild‑type (no sensitising mutations)
# • Intermediate tumor mutational burden (reported)
#
# Treatment history:
# # 3/2017 – ~7/2017: Platinum doublet – carboplatin AUC 5 plus pemetrexed 500 mg/m² IV q21 days (≈4 cycles). Best response: partial response of primary lung lesion (≈25 % decrease) but intracranial progression. Toxicities: Grade 3 neutropenia (managed with filgrastim).
# # 8/2017 – early 2018: Docetaxel 75 mg/m² IV q21 days (later dose‑reduced to 60 mg/m² because of Grade 2 peripheral neuropathy). Received at least 3 cycles (documented third cycle 9/27/2017) and continued through early 2018 (total ≤6 cycles). Best response: extracranial disease stable; brain lesion continued to enlarge. Toxicities: peripheral neuropathy, managed with duloxetine/gabapentin.
# # 12/2017 – 31/12/2017: Whole‑brain radiation therapy – 30 Gy in 10 fractions (delivered over two weeks). Completed late December 2017. Outcome: post‑therapy MRI showed stable treated lesion (size ~1.1 cm). Side effects: Grade 1 acute scalp dermatitis (resolved).
# # Early 2018 (≈1/2018 – ~2/2018): Off‑label osimertinib 80 mg PO daily (clinical trial). Discontinued after ~4 weeks due to Grade 3 QTc prolongation (QTc ≈ 495 ms). QTc returned toward baseline (≈470 ms).
# # Throughout 2018–mid 2019: Supportive care – prophylactic trimethoprim‑ sulfamethoxazole, filgrastim/pegfilgrastim as needed, management of hypertension and hyperlipidaemia.
# # 6/2019 onward: No anticancer systemic therapy (all standard and experimental lines exhausted). Continued observation and symptom-directed care (thoracenteses for malignant pleural effusion).

# %%
import numpy as np

# 1. Extract the patient embedding of interest (index 9)
target_patient_emb = np.array(pats_df.iloc[9]['patient_embedding'])

# 2. Extract all trial embeddings as a matrix
trial_embs = np.stack(trial_df['embedding'].values)

# 3. Calculate Cosine Similarity
# Cosine Similarity = (A · B) / (||A|| * ||B||)
dot_product = np.dot(trial_embs, target_patient_emb)
norms = np.linalg.norm(trial_embs, axis=1) * np.linalg.norm(target_patient_emb)
similarities = dot_product / norms

# 4. Assign back to trial_df and sort
trial_df['similarity'] = similarities
top_trials = trial_df.sort_values('similarity', ascending=False)

top_trials[['nct_id', 'title', 'similarity']].head(10)
# Out:
#             nct_id                                              title  \
# 12581  NCT05978401  Safety, Tolerability, and Efficacy of GLS-012 ...
# 16729  NCT06356701  Tumor Nutritional Therapy in the First-line Tr...
# 16181  NCT06305962   177Lu-anti-PD-L1 sdAb in Metastatic Solid Tumors
# 23717  NCT06932952  A Dose Escalation and Expansion Trial With BYO...
# 19950  NCT06621615  Clinical Study of CVL006 Injection in Advanced...
# 20723  NCT06685653  Personalized Neoantigen MRNA Vaccine Combined ...
# 7690   NCT05357651  A Study to Assess the Safety and Efficacy of L...
# 9813   NCT05652868  Clinical Study of Antibody-Drug Conjugate MYTX...
# 14224  NCT06131398  A Study of AMG 355 Alone and in Combination Wi...
# 9820   NCT05652868  Clinical Study of Antibody-Drug Conjugate MYTX...
#
#        similarity
# 12581    0.877547
# 16729    0.869857
# 16181    0.864983
# 23717    0.864738
# 19950    0.863638
# 20723    0.859775
# 7690     0.857651
# 9813     0.855803
# 14224    0.855053
# 9820     0.854516

# %%
import plotly.express as px
from sklearn.manifold import MDS
from sklearn.metrics.pairwise import cosine_distances

# 1. Define specific trials to include and filter range
top_ids = ["NCT05978401", "NCT06685653", "NCT05652868"]
mask_ids = trial_df['nct_id'].isin(top_ids)
mask_range = trial_df['similarity'] >= 0.6

# 2. Combine specific trials with a random sample from the >=0.6 range
specific_trials = trial_df[mask_ids].copy()
remaining_pool = trial_df[mask_range & ~mask_ids]
random_sample = remaining_pool.sample(min(len(remaining_pool), 20))

sampled_trials = pd.concat([specific_trials, random_sample]).sort_values('similarity', ascending=False)

# 3. Prepare data for MDS
all_embeddings = np.vstack([
    target_patient_emb.reshape(1, -1), 
    np.stack(sampled_trials['embedding'].values)
])

# Calculate pairwise Cosine Distance (1 - Similarity)
dist_matrix = cosine_distances(all_embeddings)

# 4. Run MDS (Multidimensional Scaling)
# MDS attempts to place points such that 2D distances match original pairwise distances
mds = MDS(n_components=2, dissimilarity='precomputed', random_state=42, normalized_stress='auto')
coords = mds.fit_transform(dist_matrix)

# 5. Create a DataFrame for Plotting
plot_df = pd.DataFrame(coords, columns=['X', 'Y'])
plot_df['type'] = ['Patient'] + ['Trial'] * len(sampled_trials)
plot_df['similarity'] = [1.0] + sampled_trials['similarity'].tolist()
plot_df['title'] = ['Patient Summary'] + sampled_trials['title'].tolist()
plot_df['nct_id'] = ['N/A'] + sampled_trials['nct_id'].tolist()
plot_df['summary'] = [pats_df.iloc[9]['patient_summary']] + sampled_trials['this_space'].tolist()

# 6. Plot with Plotly
fig = px.scatter(
    plot_df, 
    x='X', 
    y='Y', 
    color='similarity', 
    symbol='type',
    hover_data=['title', 'nct_id', 'summary'],
    title='MDS Plot: Visualizing Cosine Similarity Distance',
    color_continuous_scale='Greens', 
    range_color=[0.6, 1.0],
    width=900,
    height=700
)

fig.update_traces(marker=dict(size=14, line=dict(width=1, color='DarkSlateGrey')))
fig.show()
# Out:
# /Users/jlindsay/.local/share/virtualenvs/blog-2JvymaWs/lib/python3.14/site-packages/sklearn/manifold/_mds.py:744: FutureWarning:
#
# The default value of `n_init` will change from 4 to 1 in 1.9. To suppress this warning, provide some value of `n_init`.
#
# /Users/jlindsay/.local/share/virtualenvs/blog-2JvymaWs/lib/python3.14/site-packages/sklearn/manifold/_mds.py:754: FutureWarning:
#
# The default value of `init` will change from 'random' to 'classical_mds' in 1.10. To suppress this warning, provide some value of `init`.
#
# /Users/jlindsay/.local/share/virtualenvs/blog-2JvymaWs/lib/python3.14/site-packages/sklearn/manifold/_mds.py:771: FutureWarning:
#
# The `dissimilarity` parameter is deprecated and will be removed in 1.10. Use `metric` instead.

# %%
plot_df.to_parquet("example_embedding.parquet")

# %%
for idx, x in trial_df.sort_values('similarity', ascending=False).head(10).iterrows():
    print(x['title'])
    print("--", x['nct_id'])
    print()
# Out:
# Safety, Tolerability, and Efficacy of GLS-012 and GLS-010 in Patients With Advanced Non-Small Cell Lung Cancer
# -- NCT05978401
#
# Tumor Nutritional Therapy in the First-line Treatment of Stage IV NSCLC
# -- NCT06356701
#
# 177Lu-anti-PD-L1 sdAb in Metastatic Solid Tumors
# -- NCT06305962
#
# A Dose Escalation and Expansion Trial With BYON4228 Alone and in Combination in Patients With Advanced or Metastatic Solid Tumors
# -- NCT06932952
#
# Clinical Study of CVL006 Injection in Advanced Solid Tumors
# -- NCT06621615
#
# Personalized Neoantigen MRNA Vaccine Combined with Adebrelimab in Non-Small Cell Lung Cancer Patients
# -- NCT06685653
#
# A Study to Assess the Safety and Efficacy of LB1410 in Participants With Advanced Solid Tumor or Lymphoma（Keyplus-001）
# -- NCT05357651
#
# Clinical Study of Antibody-Drug Conjugate MYTX-011 in Subjects With Non-Small Cell Lung Cancer
# -- NCT05652868
#
# A Study of AMG 355 Alone and in Combination With Pembrolizumab in Participants With Advanced Solid Tumors
# -- NCT06131398
#
# Clinical Study of Antibody-Drug Conjugate MYTX-011 in Subjects With Non-Small Cell Lung Cancer
# -- NCT05652868

# %%
plot_df.summary.values[0]
# Out:
# 'Age: 60  \nSex: Male  \n\nCancer type: Non‑small cell lung cancer (NSCLC) – Adenocarcinoma, primary site left upper lobe  \n\nHistology: Moderately differentiated adenocarcinoma (predominantly acinar/tubular with focal lepidic)  \n\nCurrent extent: Metastatic (Stage\u202fIV, cT2a\u202fN2\u202fM1c) – active extrathoracic disease includes adrenal, hepatic, osseous (L3 vertebra, left iliac bone) and pleural metastases; solitary left frontal brain metastasis treated with whole‑brain radiation and currently stable  \n\nBiomarkers:  \n• PD‑L1 TPS\xa0=\xa020\u202f% (22C3)  \n• KRAS G12C mutation (exon\u202f2)  \n• MET amplification (~8 copy number)  \n• TP53 R175H missense mutation  \n• STK11 loss  \n• CDKN2A homozygous deletion  \n• Low‑level PTEN loss  \n• EGFR wild‑type (no sensitising mutations)  \n• Intermediate tumor mutational burden (reported)  \n\nTreatment history:  \n# 3/2017\u202f–\u202f~7/2017: Platinum doublet – carboplatin AUC\u202f5 plus pemetrexed 500\u202fmg/m² IV q21\u202fdays (≈4 cycles). Best response: partial response of primary lung lesion (≈25\u202f% decrease) but intracranial progression. Toxicities: Grade\u202f3 neutropenia (managed with filgrastim).  \n# 8/2017\u202f–\u202fearly\u202f2018: Docetaxel 75\u202fmg/m² IV q21\u202fdays (later dose‑reduced to 60\u202fmg/m² because of Grade\u202f2 peripheral neuropathy). Received at least 3 cycles (documented third cycle 9/27/2017) and continued through early 2018 (total ≤6 cycles). Best response: extracranial disease stable; brain lesion continued to enlarge. Toxicities: peripheral neuropathy, managed with duloxetine/gabapentin.  \n# 12/2017\u202f–\u202f31/12/2017: Whole‑brain radiation therapy – 30\u202fGy in 10 fractions (delivered over two weeks). Completed late December\u202f2017. Outcome: post‑therapy MRI showed stable treated lesion (size ~1.1\u202fcm). Side effects: Grade\u202f1 acute scalp dermatitis (resolved).  \n# Early\u202f2018 (≈1/2018\u202f–\u202f~2/2018): Off‑label osimertinib 80\u202fmg PO daily (clinical trial). Discontinued after ~4\u202fweeks due to Grade\u202f3 QTc prolongation (QTc\u202f≈\u202f495\u202fms). QTc returned toward baseline (≈470\u202fms).  \n# Throughout 2018–mid\u202f2019: Supportive care – prophylactic trimethoprim‑ sulfamethoxazole, filgrastim/pegfilgrastim as needed, management of hypertension and hyperlipidaemia.  \n# 6/2019 onward: No anticancer systemic therapy (all standard and experimental lines exhausted). Continued observation and symptom-directed care (thoracenteses for malignant pleural effusion).  \n\n'
